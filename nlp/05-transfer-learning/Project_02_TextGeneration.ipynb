# %% [markdown]
# <a href="https://colab.research.google.com/github/IrumShehryar/ML-NLP-Coursework/blob/main/nlp/05-transfer-learning/Project_02_TextGeneration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers

# %%
from transformers import pipeline

import textwrap
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from pprint import pprint

# %%
text_gen = pipeline("text-generation")
# Out:
# [transformers] No model was supplied, defaulted to HuggingFaceTB/SmolLM3-3B and revision a07cc9a.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/1.92k [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.9k [00:00<?, ?B/s]
# ...
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# ...
# Loading weights:   0%|          | 0/326 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/182 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/50.4k [00:00<?, ?B/s]
# tokenizer.json: reconstructing file:   0%|          |  0.00B / 17.2MB
# tokenizer.json: downloading bytes:           |  0.00B
# special_tokens_map.json:   0%|          | 0.00/289 [00:00<?, ?B/s]
# ...

# %%
sentence = " Deep Learning has revolutionized Artificial Intelligence"  # you can put your large text as well.

# %%
text_gen(sentence)
# Out:
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=20) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Ignoring clean_up_tokenization_spaces=True for BPE tokenizer TokenizersBackend. The clean_up_tokenization post-processing step is designed for WordPiece tokenizers and is destructive for BPE (it strips spaces before punctuation). Set clean_up_tokenization_spaces=False to suppress this warning, or set clean_up_tokenization_spaces_for_bpe_even_though_it_will_corrupt_output=True to force cleanup anyway.
# ...

# %%
print(text_gen(sentence, max_length=200))
# Out:
# [transformers] Passing `generation_config` together with generation-related arguments=({'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=200) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ...

# %%
pprint(text_gen(sentence, max_length=200)) # pretty printer
# Out:
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=200) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': ' Deep Learning has revolutionized Artificial Intelligence '
#                     '(AI) in recent years, particularly in the domain of '
#                     'Natural Language Processing (NLP). This is evident in the '
#                     'development of Large Language Models (LLMs) that can '
#                     'process and generate human-like text with remarkable '
#                     'accuracy. However, the rapid advancement of these models '
#                     'has raised concerns about their potential misuse, such as '
#                     'generating false information, deepfakes, and propaganda.\n'
#                     '\n'
# ...

# %%
pprint(text_gen(sentence, num_return_sequences=3, max_length=40)) # Text generation is random because
                                                                   # it is generated from probability distribution
# Out:
# [transformers] Passing `generation_config` together with generation-related arguments=({'num_return_sequences', 'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': ' Deep Learning has revolutionized Artificial Intelligence '
#                     'by enabling machines to learn from data, recognize '
#                     'patterns, and make predictions with high accuracy.\n'
#                     '\n'
#                     'In the field of Machine Learning, there are two main '
#                     'branches: Supervised Learning and Unsupervised Learning.\n'
# ...

# %%
sentence  = "The quick brown fox jumps over the lazy dog and the quick white cat jumps over the lazy rabbit"

# %%
pprint(text_gen(sentence, num_return_sequences=5, max_length=40))
# Out:
# [transformers] Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'The quick brown fox jumps over the lazy dog and the quick '
#                     'white cat jumps over the lazy rabbit. The quick brown fox '
#                     'jumps over the lazy dog and the quick white cat jumps '
#                     'over the lazy rabbit again. The quick brown fox jumps '
#                     'over the lazy dog, and the quick white cat jumps over the '
#                     'lazy rabbit, but this time the fox is faster than before. '
#                     'The quick brown fox jumps over the lazy dog, the quick '
#                     'white cat jumps over the lazy rabbit, and both the fox '
#                     'and the cat are running at their maximum speed. The quick '
# ...
