# %% [markdown]
# <a href="https://colab.research.google.com/github/IrumShehryar/ML-NLP-Coursework/blob/main/nlp/neural-network/Project02_TextClassification_bbcDataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from matplotlib import style
style.use('dark_background')
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/NLP-course/Course Material/Neural Networks For Text Classification
# Out:
# /content/drive/MyDrive/NLP-course/Course Material/Neural Networks For Text Classification

# %%
df = pd.read_csv('bbc-text.csv')

# %%
df.head()
# Out:
#         category                                               text
# 0           tech  tv future in the hands of viewers with home th...
# 1       business  worldcom boss  left books alone  former worldc...
# 2          sport  tigers wary of farrell  gamble  leicester say ...
# 3          sport  yeading face newcastle in fa cup premiership s...
# 4  entertainment  ocean s twelve raids box office ocean s twelve...

# %% [markdown]
# # Change column names to label and text

# %%
df.columns = ['labels', 'text']

# %%
df.head()
# Out:
#           labels                                               text
# 0           tech  tv future in the hands of viewers with home th...
# 1       business  worldcom boss  left books alone  former worldc...
# 2          sport  tigers wary of farrell  gamble  leicester say ...
# 3          sport  yeading face newcastle in fa cup premiership s...
# 4  entertainment  ocean s twelve raids box office ocean s twelve...

# %% [markdown]
# # Check if the data is balanced

# %%
plt.figure(figsize = (8,6))
x, y = np.unique(df['labels'], return_counts=True)
plt.bar(x, y, align='center')
plt.gca().set_xticks(x)
plt.show()

# %%
df['labels'].value_counts()
# Out:
# labels
# sport            511
# business         510
# politics         417
# tech             401
# entertainment    386
# Name: count, dtype: int64

# %% [markdown]
# # Convert Labels into integers

# %%
df['labels'] = df['labels'].map({'sport': 0, 'business': 1, 'politics': 2, 'tech': 3, 'entertainment': 4})

# %%
df.head()
# Out:
#    labels                                               text
# 0       3  tv future in the hands of viewers with home th...
# 1       1  worldcom boss  left books alone  former worldc...
# 2       0  tigers wary of farrell  gamble  leicester say ...
# 3       0  yeading face newcastle in fa cup premiership s...
# 4       4  ocean s twelve raids box office ocean s twelve...

# %% [markdown]
# # Check for Null Values

# %%
df.isnull().any()
# Out:
# labels    False
# text      False
# dtype: bool

# %% [markdown]
# # Extarct features and labels

# %%
features = df['text']
labels = df['labels']

# %% [markdown]
# # Perform train-test split

# %%
train_data, test_data, train_labels, test_labels = train_test_split(features, labels, test_size = 0.2, random_state = 42)

# %% [markdown]
# # Instantiate TFIDF Vectorizer and fit and tranform on training and testing data

# %%
vectorizer = TfidfVectorizer(stop_words='english')
X_train = vectorizer.fit_transform(train_data)
X_test = vectorizer.transform(test_data)

# %%
X_train
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 257235 stored elements and shape (1780, 26327)>

# %% [markdown]
# ## Data must not be sparse matrix type before passing into tensorflow. Convert them to array.

# %%
X_train = X_train.toarray()
X_test = X_test.toarray()

# %% [markdown]
# # Check the dimensionality OR features in input data

# %%
D = X_train.shape[1]
print(D)
# Out:
# 26327

# %% [markdown]
# # Create Neural Network Model

# %%
model = Sequential()
model.add(Dense(units = 256, input_shape =(D, ), activation = 'relu'))
model.add(Dense(units = 64, activation = 'relu'))
model.add(Dense(units = 32, activation = 'relu'))
model.add(Dense(units = 5, activation = 'softmax'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 256)            │     6,739,968 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │        16,448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 5)              │           165 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,758,661 (25.78 MB)
#  Trainable params: 6,758,661 (25.78 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # Compile the Model

# %%
model.compile(optimizer = tf.keras.optimizers.SGD(learning_rate = 0.01) ,loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# # Train the Model

# %%
train = model.fit(
  X_train, train_labels,
  validation_data=(X_test, test_labels),
  epochs = 60,
)
# Out:
# Epoch 1/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - accuracy: 0.2258 - loss: 1.6074 - val_accuracy: 0.2382 - val_loss: 1.6060
# Epoch 2/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.2371 - loss: 1.6029 - val_accuracy: 0.2292 - val_loss: 1.6030
# Epoch 3/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.2376 - loss: 1.5993 - val_accuracy: 0.2337 - val_loss: 1.6006
# Epoch 4/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.2657 - loss: 1.5960 - val_accuracy: 0.2494 - val_loss: 1.5980
# Epoch 5/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.2719 - loss: 1.5924 - val_accuracy: 0.3034 - val_loss: 1.5948
# Epoch 6/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.3438 - loss: 1.5882 - val_accuracy: 0.2494 - val_loss: 1.5909
# Epoch 7/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.3034 - loss: 1.5833 - val_accuracy: 0.3506 - val_loss: 1.5864
# Epoch 8/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.3815 - loss: 1.5775 - val_accuracy: 0.3506 - val_loss: 1.5806
# Epoch 9/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - accuracy: 0.3612 - loss: 1.5709 - val_accuracy: 0.4157 - val_loss: 1.5748
# Epoch 10/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - accuracy: 0.4343 - loss: 1.5640 - val_accuracy: 0.3663 - val_loss: 1.5679
# Epoch 11/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.4444 - loss: 1.5561 - val_accuracy: 0.3730 - val_loss: 1.5609
# Epoch 12/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.4494 - loss: 1.5476 - val_accuracy: 0.4944 - val_loss: 1.5524
# Epoch 13/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.4989 - loss: 1.5385 - val_accuracy: 0.4944 - val_loss: 1.5435
# Epoch 14/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - accuracy: 0.5067 - loss: 1.5282 - val_accuracy: 0.5124 - val_loss: 1.5337
# Epoch 15/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.5455 - loss: 1.5170 - val_accuracy: 0.5146 - val_loss: 1.5230
# Epoch 16/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - accuracy: 0.5567 - loss: 1.5045 - val_accuracy: 0.5393 - val_loss: 1.5107
# Epoch 17/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.5792 - loss: 1.4910 - val_accuracy: 0.5685 - val_loss: 1.4975
# Epoch 18/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.6107 - loss: 1.4754 - val_accuracy: 0.5753 - val_loss: 1.4823
# Epoch 19/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - accuracy: 0.6388 - loss: 1.4584 - val_accuracy: 0.6202 - val_loss: 1.4661
# Epoch 20/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.6719 - loss: 1.4388 - val_accuracy: 0.6225 - val_loss: 1.4473
# Epoch 21/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.6916 - loss: 1.4178 - val_accuracy: 0.6315 - val_loss: 1.4272
# Epoch 22/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - accuracy: 0.7112 - loss: 1.3933 - val_accuracy: 0.6742 - val_loss: 1.4032
# Epoch 23/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.7354 - loss: 1.3657 - val_accuracy: 0.7416 - val_loss: 1.3777
# Epoch 24/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - accuracy: 0.7596 - loss: 1.3350 - val_accuracy: 0.7213 - val_loss: 1.3469
# Epoch 25/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 59ms/step - accuracy: 0.7736 - loss: 1.3006 - val_accuracy: 0.7551 - val_loss: 1.3140
# Epoch 26/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.7893 - loss: 1.2617 - val_accuracy: 0.7865 - val_loss: 1.2759
# Epoch 27/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.8056 - loss: 1.2186 - val_accuracy: 0.7820 - val_loss: 1.2349
# Epoch 28/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.8169 - loss: 1.1705 - val_accuracy: 0.8045 - val_loss: 1.1913
# Epoch 29/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.8365 - loss: 1.1188 - val_accuracy: 0.8180 - val_loss: 1.1398
# Epoch 30/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.8567 - loss: 1.0625 - val_accuracy: 0.8292 - val_loss: 1.0870
# Epoch 31/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 52ms/step - accuracy: 0.8680 - loss: 1.0030 - val_accuracy: 0.8382 - val_loss: 1.0318
# Epoch 32/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.8938 - loss: 0.9391 - val_accuracy: 0.8225 - val_loss: 0.9792
# Epoch 33/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9022 - loss: 0.8760 - val_accuracy: 0.8787 - val_loss: 0.9149
# Epoch 34/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9326 - loss: 0.8098 - val_accuracy: 0.8944 - val_loss: 0.8528
# Epoch 35/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9404 - loss: 0.7455 - val_accuracy: 0.9236 - val_loss: 0.7932
# Epoch 36/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 8s 143ms/step - accuracy: 0.9562 - loss: 0.6813 - val_accuracy: 0.9213 - val_loss: 0.7374
# Epoch 37/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 5s 85ms/step - accuracy: 0.9607 - loss: 0.6204 - val_accuracy: 0.9438 - val_loss: 0.6808
# Epoch 38/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9713 - loss: 0.5626 - val_accuracy: 0.9393 - val_loss: 0.6311
# Epoch 39/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.9770 - loss: 0.5100 - val_accuracy: 0.9461 - val_loss: 0.5830
# Epoch 40/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9803 - loss: 0.4620 - val_accuracy: 0.9438 - val_loss: 0.5401
# Epoch 41/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9837 - loss: 0.4169 - val_accuracy: 0.9551 - val_loss: 0.5017
# Epoch 42/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9871 - loss: 0.3780 - val_accuracy: 0.9483 - val_loss: 0.4680
# Epoch 43/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.9882 - loss: 0.3430 - val_accuracy: 0.9506 - val_loss: 0.4363
# Epoch 44/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9888 - loss: 0.3113 - val_accuracy: 0.9483 - val_loss: 0.4087
# Epoch 45/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - accuracy: 0.9899 - loss: 0.2829 - val_accuracy: 0.9528 - val_loss: 0.3842
# Epoch 46/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - accuracy: 0.9899 - loss: 0.2584 - val_accuracy: 0.9551 - val_loss: 0.3650
# Epoch 47/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 39ms/step - accuracy: 0.9910 - loss: 0.2361 - val_accuracy: 0.9573 - val_loss: 0.3458
# Epoch 48/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9927 - loss: 0.2164 - val_accuracy: 0.9528 - val_loss: 0.3281
# Epoch 49/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9938 - loss: 0.1987 - val_accuracy: 0.9551 - val_loss: 0.3097
# Epoch 50/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.9927 - loss: 0.1830 - val_accuracy: 0.9528 - val_loss: 0.2957
# Epoch 51/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - accuracy: 0.9938 - loss: 0.1691 - val_accuracy: 0.9506 - val_loss: 0.2856
# Epoch 52/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.9944 - loss: 0.1563 - val_accuracy: 0.9573 - val_loss: 0.2731
# Epoch 53/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9949 - loss: 0.1447 - val_accuracy: 0.9573 - val_loss: 0.2624
# Epoch 54/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9955 - loss: 0.1341 - val_accuracy: 0.9528 - val_loss: 0.2542
# Epoch 55/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 0.9949 - loss: 0.1251 - val_accuracy: 0.9596 - val_loss: 0.2478
# Epoch 56/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - accuracy: 0.9961 - loss: 0.1164 - val_accuracy: 0.9573 - val_loss: 0.2386
# Epoch 57/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9961 - loss: 0.1090 - val_accuracy: 0.9551 - val_loss: 0.2293
# Epoch 58/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9961 - loss: 0.1021 - val_accuracy: 0.9551 - val_loss: 0.2236
# Epoch 59/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - accuracy: 0.9961 - loss: 0.0954 - val_accuracy: 0.9551 - val_loss: 0.2204
# Epoch 60/60
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.9961 - loss: 0.0898 - val_accuracy: 0.9551 - val_loss: 0.2123

# %% [markdown]
# # Visualizing Model Performance

# %%
trainAcc = [100 * x for x in train.history['accuracy']]
testAcc = [100 * x for x in train.history['val_accuracy']]

# %%
fig,ax = plt.subplots(1,2,figsize=(18,6))

ax[0].plot(train.history['loss'], 'g', lw = 3, label = 'Train')
ax[0].set_xlabel('Epochs', fontsize = 15)
ax[0].set_ylabel('Loss', fontsize = 15)
ax[0].legend(fontsize = 15)
ax[0].set_title('Training Loss', fontsize = 15)


ax[1].plot(trainAcc, label ='Train', lw = 3)
ax[1].plot(testAcc, label ='Test', lw = 3)
ax[1].set_xlabel('Epochs', fontsize = 15)
ax[1].set_ylabel('Accuracy (%)', fontsize = 15)
ax[1].set_ylim([10,110])
ax[1].set_title(f'Train Accuracy: {trainAcc[-1]:.2f}% \n Test Accuracy: {testAcc[-1]:.2f}%', fontsize = 15)
ax[1].legend(fontsize = 15)

plt.show()

# %% [markdown]
# # Observe the Predicted Labels

# %%
y_pred = model.predict(X_test)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step

# %%
y_pred.round(2)
# Out:
# array([[0.  , 0.  , 0.99, 0.  , 0.01],
#        [0.01, 0.98, 0.  , 0.01, 0.  ],
#        [0.02, 0.  , 0.02, 0.  , 0.97],
#        ...,
#        [0.01, 0.99, 0.  , 0.  , 0.  ],
#        [0.  , 0.98, 0.  , 0.02, 0.  ],
#        [0.09, 0.61, 0.05, 0.19, 0.07]], dtype=float32)

# %%
pred_labels = np.argmax(y_pred, axis = 1)

# %%
pred_labels
# Out:
# array([2, 1, 4, 3, 0, 1, 3, 0, 0, 3, 4, 4, 4, 4, 4, 3, 2, 0, 4, 1, 4, 4,
#        1, 2, 2, 2, 2, 0, 4, 0, 2, 3, 2, 4, 1, 4, 3, 1, 3, 0, 1, 0, 4, 1,
#        4, 4, 1, 0, 4, 0, 2, 0, 4, 4, 4, 1, 2, 1, 4, 1, 4, 3, 1, 1, 2, 0,
#        0, 4, 1, 1, 4, 1, 3, 3, 3, 2, 3, 4, 1, 3, 1, 2, 2, 4, 2, 0, 0, 4,
#        0, 0, 2, 4, 3, 1, 2, 1, 0, 2, 2, 3, 1, 3, 0, 0, 3, 1, 2, 1, 4, 2,
#        0, 2, 2, 0, 3, 0, 0, 1, 4, 2, 2, 0, 2, 4, 4, 0, 3, 2, 0, 4, 3, 2,
#        1, 1, 0, 3, 4, 1, 2, 2, 0, 1, 0, 4, 4, 0, 4, 4, 3, 1, 4, 3, 4, 1,
#        3, 2, 0, 2, 2, 0, 3, 3, 0, 0, 1, 0, 3, 0, 2, 0, 1, 2, 1, 2, 3, 0,
#        0, 4, 1, 0, 3, 3, 2, 3, 2, 3, 3, 3, 4, 2, 3, 3, 0, 1, 2, 3, 2, 3,
#        1, 0, 2, 3, 3, 0, 0, 1, 4, 0, 1, 4, 2, 4, 1, 2, 0, 1, 1, 4, 0, 2,
#        0, 2, 2, 2, 0, 4, 3, 4, 2, 1, 3, 2, 3, 4, 1, 0, 0, 2, 0, 0, 2, 1,
#        1, 4, 4, 0, 2, 3, 0, 1, 2, 1, 0, 3, 0, 1, 1, 0, 3, 3, 4, 3, 4, 2,
#        4, 2, 2, 0, 1, 2, 3, 3, 4, 4, 4, 0, 0, 1, 0, 3, 4, 3, 0, 0, 0, 2,
#        4, 4, 0, 4, 1, 0, 0, 2, 1, 0, 3, 1, 1, 1, 2, 1, 3, 2, 3, 2, 2, 3,
#        3, 2, 1, 0, 0, 1, 3, 1, 1, 2, 4, 2, 0, 0, 0, 4, 0, 0, 0, 0, 0, 0,
#        4, 4, 0, 1, 1, 1, 0, 3, 3, 0, 3, 3, 3, 2, 0, 4, 0, 1, 2, 3, 3, 2,
#        0, 0, 1, 4, 4, 1, 2, 2, 1, 1, 3, 2, 0, 0, 2, 0, 3, 0, 1, 3, 1, 3,
#        3, 2, 1, 1, 4, 2, 2, 2, 1, 4, 1, 2, 4, 1, 3, 1, 1, 0, 3, 0, 1, 1,
#        4, 2, 1, 2, 4, 2, 1, 4, 2, 1, 0, 3, 3, 3, 2, 3, 4, 3, 1, 1, 1, 1,
#        1, 1, 0, 4, 0, 0, 4, 0, 1, 3, 3, 1, 3, 3, 3, 4, 1, 3, 4, 3, 4, 1,
#        1, 1, 1, 1, 1])

# %% [markdown]
# # Print the classification Report

# %%
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score, classification_report

# %%
print("Accuracy : %2.2f" % (accuracy_score(test_labels, pred_labels, normalize=True)))
print("Precision : %2.2f" % (precision_score(test_labels, pred_labels, average = 'macro')))
print("Recall : %2.2f" % (recall_score(test_labels, pred_labels, average = 'macro')))
print("F1_Score : %2.2f" % (f1_score(test_labels, pred_labels, average = 'macro')))
# Out:
# Accuracy : 0.96
# Precision : 0.95
# Recall : 0.95
# F1_Score : 0.95

# %%
print(classification_report(test_labels, pred_labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98        98
#            1       0.95      0.93      0.94       101
#            2       0.93      0.94      0.93        83
#            3       0.95      0.98      0.96        82
#            4       0.96      0.94      0.95        81
#
#     accuracy                           0.96       445
#    macro avg       0.95      0.95      0.95       445
# weighted avg       0.96      0.96      0.95       445
