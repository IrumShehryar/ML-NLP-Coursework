# %% [markdown]
# <a href="https://colab.research.google.com/github/IrumShehryar/ML-NLP-Coursework/blob/main/nlp/04-neural-network/RNN/Project_04_Preprocessing_TextClassification_TFlow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Libraries

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %% [markdown]
# # Create Few Sentences

# %%
sentences = [
    "He is happy",
    "He is learning LSTM Network",
    "He passes his exam easily"
]

# %% [markdown]
# # Tokenization OR create Embeddings

# %%
vocab_size = 20000 # 3000 words cover 95% of english text so vacab_size = 20000 are enough
tokenizer = Tokenizer(num_words=vocab_size)
tokenizer.fit_on_texts(sentences)
sequences = tokenizer.texts_to_sequences(sentences)

# %%
print(sequences)
# Out:
# [[1, 2, 3], [1, 2, 4, 5, 6], [1, 7, 8, 9, 10]]

# %% [markdown]
# # Word to Index Mapping

# %%
tokenizer.word_index
# Out:
# {'he': 1,
#  'is': 2,
#  'happy': 3,
#  'learning': 4,
#  'lstm': 5,
#  'network': 6,
#  'passes': 7,
#  'his': 8,
#  'exam': 9,
#  'easily': 10}

# %% [markdown]
# # Pad the sequence

# %%
data = pad_sequences(sequences) # use the defaults. By Default padding is pre
print(data)
# Out:
# [[ 0  0  1  2  3]
#  [ 1  2  4  5  6]
#  [ 1  7  8  9 10]]

# %%
max_seq_len = 5
data = pad_sequences(sequences, maxlen = max_seq_len )
print(data)
# Out:
# [[ 0  0  1  2  3]
#  [ 1  2  4  5  6]
#  [ 1  7  8  9 10]]

# %%
data = pad_sequences(sequences, maxlen = max_seq_len , padding='post')
print(data)
# Out:
# [[ 1  2  3  0  0]
#  [ 1  2  4  5  6]
#  [ 1  7  8  9 10]]

# %%
data = pad_sequences(sequences, maxlen = 6) # more padding
print(data)
# Out:
# [[ 0  0  0  1  2  3]
#  [ 0  1  2  4  5  6]
#  [ 0  1  7  8  9 10]]

# %% [markdown]
# # Data Truncation

# %%
data = pad_sequences(sequences, maxlen=4)
print(data)
# Out:
# [[ 0  1  2  3]
#  [ 2  4  5  6]
#  [ 7  8  9 10]]

# %%
data = pad_sequences(sequences, maxlen=4, truncating='post')
print(data)
# Out:
# [[0 1 2 3]
#  [1 2 4 5]
#  [1 7 8 9]]
