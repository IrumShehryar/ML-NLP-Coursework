# %% [markdown]
# <a href="https://colab.research.google.com/github/IrumShehryar/ML-NLP-Coursework/blob/main/nlp/04-neural-network/neural-word-embeddings/Project04_TextClassification_Neural_Embeddings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
style.use('dark_background')
from sklearn.model_selection import train_test_split
# !pip install gensim
from gensim.models import KeyedVectors
import tensorflow as tf
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential

# %% [markdown]
# # Read the dataset

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/NLP-course/Course Material/Neural Word Embeddings (Word2Vec)

# %%
df = pd.read_csv('moviereviews.tsv', sep='\t')

# %%
df
# Out:
#      label                                             review
# 0      neg  how do films like mouse hunt get into theatres...
# 1      neg  some talented actresses are blessed with a dem...
# 2      pos  this has been an extraordinary year for austra...
# 3      pos  according to hollywood movies made in last few...
# 4      neg  my first press screening of 1998 and already i...
# ...    ...                                                ...
# 1995   pos  i like movies with albert brooks , and i reall...
# 1996   pos  it might surprise some to know that joel and e...
# 1997   pos  the verdict : spine-chilling drama from horror...
# 1998   pos  i want to correct what i wrote in a former ret...
# 1999   pos  a couple of months ago , when i first download...
#
# [2000 rows x 2 columns]

# %% [markdown]
# # Check the Null Values

# %%
df.isnull().any()
# Out:
# label     False
# review     True
# dtype: bool

# %%
df.dropna(inplace = True)

# %%
df.isnull().any()
# Out:
# label     False
# review    False
# dtype: bool

# %% [markdown]
# # Check if the data is balance

# %%
df['label'].value_counts()
# Out:
# label
# neg    983
# pos    982
# Name: count, dtype: int64

# %% [markdown]
# # Change the columns name to labels and text

# %%
df.columns = ['labels', 'text']

# %% [markdown]
# # Convert labels to integers

# %%
df['labels'] = df['labels'].map({'pos': 0, 'neg': 1})

# %%
df.head()
# Out:
#    labels                                               text
# 0       1  how do films like mouse hunt get into theatres...
# 1       1  some talented actresses are blessed with a dem...
# 2       0  this has been an extraordinary year for austra...
# 3       0  according to hollywood movies made in last few...
# 4       1  my first press screening of 1998 and already i...

# %% [markdown]
# # Extract features and labels

# %%
features = df['text']
labels = df['labels']

# %% [markdown]
# # Split the data into training and testing

# %%
train_data, test_data, train_labels, test_labels = train_test_split(features, labels, test_size = 0.2, random_state = 42)

# %% [markdown]
# # Import Word2Vec Vectorizer

# %%
from Word2VecVectorizer import Word2VecVectorizer

# %%
vectorizer = Word2VecVectorizer()
# Out:
# Loading in word vectors...
# Finished loading in word vectors

# %% [markdown]
# # Vectorize Training and Testing data

# %%
Xtrain = vectorizer.fit_transform(train_data)
Xtest = vectorizer.transform(test_data)
# Out:
# Numer of samples with no words found: 21 / 1572
# Numer of samples with no words found: 6 / 393

# %%
type(Xtrain)
# Out:
# numpy.ndarray

# %% [markdown]
# # Feature dimension of the input data

# %%
D = Xtrain.shape[1]
print(D)
# Out:
# 300

# %% [markdown]
# # Create the model and train it

# %%
model = Sequential()
model.add(Dense(units = 64, input_shape =(D, ), activation = 'relu'))
model.add(Dense(units = 32, activation = 'relu'))
model.add(Dense(units = 2, activation = 'softmax'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(optimizer = tf.keras.optimizers.SGD(learning_rate = 0.01) ,loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
train = model.fit(
  Xtrain, train_labels,
  validation_data=(Xtest, test_labels),
  epochs = 60,
)
# Out:
# Epoch 1/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.5534 - loss: 0.6913 - val_accuracy: 0.5547 - val_loss: 0.6920
# Epoch 2/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5522 - loss: 0.6909 - val_accuracy: 0.5369 - val_loss: 0.6913
# Epoch 3/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5687 - loss: 0.6907 - val_accuracy: 0.5267 - val_loss: 0.6910
# Epoch 4/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.
60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6565 - loss: 0.6782 - val_accuracy: 0.5903 - val_loss: 0.6827
# Epoch 38/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6393 - loss: 0.6777 - val_accuracy: 0.5980 - val_loss: 0.6815
# Epoch 39/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6654 - loss: 0.6775 - val_accuracy: 0.6005 - val_loss: 0.6812
# Epoch 40/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6609 - loss: 0.6772 - val_accuracy: 0.5929 - val_loss: 0.6814
# Epoch 41/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6463 - loss: 0.6762 - val_accuracy: 0.6107 - val_loss: 0.6804
# Epoch 42/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6768 - loss: 0.6759 - val_accuracy: 0.6031 - val_loss: 0.6804
# Epoch 43/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6705 - loss: 0.6753 - val_accuracy: 0.5649 - val_loss: 0.6812
# Epoch 44/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6724 - loss: 0.6749 - val_accuracy: 0.6234 - val_loss: 0.6794
# Epoch 45/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6679 - loss: 0.6740 - val_accuracy: 0.6234 - val_loss: 0.6787
# Epoch 46/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6711 - loss: 0.6737 - val_accuracy: 0.6209 - val_loss: 0.6783
# Epoch 47/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6622 - loss: 0.6731 - val_accuracy: 0.6005 - val_loss: 0.6786
# Epoch 48/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6845 - loss: 0.6724 - val_accuracy: 0.6234 - val_loss: 0.6775
# Epoch 49/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6775 - loss: 0.6720 - val_accuracy: 0.6336 - val_loss: 0.6770
# Epoch 50/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6768 - loss: 0.6714 - val_accuracy: 0.5573 - val_loss: 0.6792
# Epoch 51/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6679 - loss: 0.6710 - val_accuracy: 0.6081 - val_loss: 0.6769
# Epoch 52/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6686 - loss: 0.6698 - val_accuracy: 0.6285 - val_loss: 0.6754
# Epoch 53/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6819 - loss: 0.6692 - val_accuracy: 0.6056 - val_loss: 0.6749
# Epoch 54/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6781 - loss: 0.6687 - val_accuracy: 0.6005 - val_loss: 0.6749
# Epoch 55/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.6724 - loss: 0.6676 - val_accuracy: 0.5700 - val_loss: 0.6756
# Epoch 56/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6654 - loss: 0.6667 - val_accuracy: 0.6183 - val_loss: 0.6732
# Epoch 57/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6838 - loss: 0.6663 - val_accuracy: 0.6005 - val_loss: 0.6731
# Epoch 58/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.6877 - loss: 0.6652 - val_accuracy: 0.5827 - val_loss: 0.6736
# Epoch 59/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.6730 - loss: 0.6648 - val_accuracy: 0.6387 - val_loss: 0.6715
# Epoch 60/60
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6807 - loss: 0.6640 - val_accuracy: 0.6031 - val_loss: 0.6715

# %%
trainAcc = [100 * x for x in train.history['accuracy']]
testAcc = [100 * x for x in train.history['val_accuracy']]

# %%
fig,ax = plt.subplots(1,2,figsize=(18,6))

ax[0].plot(train.history['loss'], 'g', lw = 3, label = 'Train')
ax[0].set_xlabel('Epochs', fontsize = 15)
ax[0].set_ylabel('Loss', fontsize = 15)
ax[0].legend(fontsize = 15)
ax[0].set_title('Training Loss', fontsize = 15)


ax[1].plot(trainAcc, label ='Train', lw = 3)
ax[1].plot(testAcc, label ='Test', lw = 3)
ax[1].set_xlabel('Epochs', fontsize = 15)
ax[1].set_ylabel('Accuracy (%)', fontsize = 15)
ax[1].set_ylim([10,110])
ax[1].set_title(f'Train Accuracy: {trainAcc[-1]:.2f}% \n Test Accuracy: {testAcc[-1]:.2f}%', fontsize = 15)
ax[1].legend(fontsize = 15)

plt.show()
