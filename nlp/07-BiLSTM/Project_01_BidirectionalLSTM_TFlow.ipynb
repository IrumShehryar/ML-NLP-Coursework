# %% [markdown]
# <a href="https://colab.research.google.com/github/IrumShehryar/ML-NLP-Coursework/blob/main/nlp/07-BiLSTM/Project_01_BidirectionalLSTM_TFlow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.models import Model
from keras.layers import Input, LSTM, Bidirectional
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 1-When retrun_sequences = True, return_state = False

# %%
T = 4  # time steps
D = 2 # features
H = 3 # LSTM Units

# %% [markdown]
# ### Create the input data

# %%
X = np.random.randn(1, T, D)
print("Input shape", X.shape)
# Out:
# Input shape (1, 4, 2)

# %% [markdown]
# ### Create LSTM Model

# %%
input = Input(shape=(T, D))
Bi_LSTM = Bidirectional(LSTM(H, return_sequences = True,  return_state = False,))

x = Bi_LSTM(input)

model1 = Model(inputs=input, outputs=x)

# %% [markdown]
# ### Get the output from the model

# %%
output = model1.predict(X)
print("\nOutput.shape is T x 2H :", output.shape) # T X 2H
print("\n\nOutput represents the hidden states of all the time steps")
print("\n The hidden state of the bidirectional LSTM is the concatenation of forward and reverse LSTM")
print("\nOutput:", output)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
#
# Output.shape is T x 2H : (1, 4, 6)
#
#
# Output represents the hidden states of all the time steps
#
#  The hidden state of the bidirectional LSTM is the concatenation of forward and reverse LSTM
#
# Output: [[[ 0.07690373  0.10181513 -0.00761842  0.10724558  0.06813518
#    -0.071008  ]
#   [ 0.03122372  0.11419307 -0.24894759  0.0674632   0.11206491
#     0.03805118]
#   [-0.02488839 -0.07044321 -0.03912004 -0.07706991 -0.24044381
#     0.02165119]
#   [-0.00121369 -0.07153863  0.06897035 -0.06125174 -0.13646862
#    -0.05294403]]]

# %% [markdown]
# # 2-When return_sequences = False, return_state = True

# %% [markdown]
# ### Create LSTM Model

# %%
input = Input(shape=(T, D))
Bi_LSTM = Bidirectional(LSTM(H, return_sequences = False, return_state = True))

x = Bi_LSTM(input)

model2 = Model(inputs=input, outputs=x)

# %% [markdown]
# ### Get the output from the model

# %%
output, h1, c1, h2, c2 = model2.predict(X)
print("\nOutput:", output) # Concatenation of both hidden states 1.e forward and reverse.
print("\nOutput.shape:", output.shape)
print("\nh1:", h1)
print("\nc1:", c1)
print("\nh2:", h2)
print("\nc2:", c2)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7e08ac529bc0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step
#
# Output: [[-0.05811065 -0.07402443 -0.01625801  0.1074225  -0.26297396 -0.06478592]]
#
# Output.shape: (1, 6)
#
# h1: [[-0.05811065 -0.07402443 -0.01625801]]
#
# c1: [[-0.13218907 -0.17428444 -0.03069858]]
#
# h2: [[ 0.1074225  -0.26297396 -0.06478592]]
#
# c2: [[ 0.23373777 -0.44781947 -0.12686312]]

# %% [markdown]
# # 3-When return_sequences = True, return_state = True

# %% [markdown]
# ### Create LSTM

# %%
input = Input(shape=(T, D))
Bi_LSTM = Bidirectional(LSTM(H, return_state = True, return_sequences = True))

x = Bi_LSTM(input)

model3 = Model(inputs=input, outputs=x)

# %% [markdown]
# ### Get the output from the LSTM

# %%
output, h1, c1, h2, c2 = model3.predict(X)
print("\nOutput:", output)
print("\nh1:", h1)
print("\nc1:", c1)
print("\nh2:", h2) # h2 is the final hidden state for the backward LSTM. So going from front to back the final hidden state for
                 # backward LSTM should be at the front of the sequence
print("c2:", c2)
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7e08ac5ba5c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
#
# Output: [[[ 0.11509497 -0.01449903 -0.0529387  -0.00033988 -0.07686128
#    -0.04577055]
#   [ 0.15170723 -0.05277604 -0.283711   -0.03084474 -0.03555816
#    -0.0405099 ]
#   [ 0.00660277 -0.03525056 -0.01761102 -0.03033611  0.03205037
#     0.10370774]
#   [-0.03503305 -0.01015814  0.06158583 -0.00730264  0.0184154
#     0.04797907]]]
#
# h1: [[-0.03503305 -0.01015814  0.06158583]]
#
# c1: [[-0.08068457 -0.02234724  0.164215  ]]
#
# h2: [[-0.00033988 -0.07686128 -0.04577055]]
# c2: [[-0.00050564 -0.14247851 -0.11561114]]
