# %% [markdown]
# <a href="https://colab.research.google.com/github/IrumShehryar/ML-NLP-Coursework/blob/main/nlp/Project01_SpamDetection_Naive_Bayes_Classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
from matplotlib import style
style.use('dark_background')
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, confusion_matrix
from sklearn.naive_bayes import MultinomialNB

# %% [markdown]
# # Mount the drive and read the dataset

# %%
# %cd /content/drive/MyDrive/NLP-course/Course Material/Text Classification - Spam Detection
# Out:
# /content/drive/MyDrive/NLP-course/Course Material/Text Classification - Spam Detection

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('spam.csv', encoding='ISO-8859-1')

# %%
df.shape
# Out:
# (5572, 5)

# %%
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %% [markdown]
# # Drop irrelevant columns

# %%
df = df.drop(["Unnamed: 2", "Unnamed: 3", "Unnamed: 4"], axis=1)

# %%
df.head()
# Out:
#      v1                                                 v2
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# # Change column names to text and labels

# %%
df.columns = ['labels', 'text']

# %%
df.head()
# Out:
#   labels                                               text
# 0    ham  Go until jurong point, crazy.. Available only ...
# 1    ham                      Ok lar... Joking wif u oni...
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3    ham  U dun say so early hor... U c already then say...
# 4    ham  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# # Check if the data is balanced

# %%
plt.figure(figsize = (8,6))
x, y = np.unique(df['labels'], return_counts=True)
plt.bar(x, y, align='center')
plt.gca().set_xticks(x)
plt.show()

# %%
df['labels'].value_counts()
# Out:
# labels
# ham     4825
# spam     747
# Name: count, dtype: int64

# %% [markdown]
# # Tansform Labels into numbers

# %%
df['labels'] = df['labels'].map({'ham': 0, 'spam': 1})

# %%
df.head()
# Out:
#    labels                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %% [markdown]
# # Extract features and labels from the data

# %% [markdown]
# ### Alternative way to extract features and labels

# %%
# This creates 'features_series' as a pandas Series
features_series = df['text']

# This creates 'labels_series' as a pandas Series
labels_series = df['labels']

print(f"Type of features_series: {type(features_series)}")
print(f"Type of labels_series: {type(labels_series)}")

# You can verify the head of these new series
print('\nfeatures_series head:')
display(features_series.head())
print('\nlabels_series head:')
display(labels_series.head())
# Out:
# Type of features_series: <class 'pandas.core.series.Series'>
# Type of labels_series: <class 'pandas.core.series.Series'>
#
# features_series head:
# 0    Go until jurong point, crazy.. Available only ...
# 1                        Ok lar... Joking wif u oni...
# 2    Free entry in 2 a wkly comp to win FA Cup fina...
# 3    U dun say so early hor... U c already then say...
# 4    Nah I don't think he goes to usf, he lives aro...
# Name: text, dtype: object
# labels_series head:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    0
# Name: labels, dtype: int64

# %%
features = df['text']
labels = df['labels'].values

# %% [markdown]
# # Split the data into training and testing

# %%
train_data, test_data, train_labels, test_labels = train_test_split(features, labels, test_size = 0.2, random_state = 42)

# %% [markdown]
# # Map the text into numbers using CountVectorizer

# %%
featurizer = CountVectorizer()
Xtrain = featurizer.fit_transform(train_data)
Xtest = featurizer.transform(test_data)

# %%
Xtrain
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 58978 stored elements and shape (4457, 7735)>

# %% [markdown]
# # Instantiate Naive Bayes Model

# %%
model = MultinomialNB()

# %% [markdown]
# # Train and test the model

# %%
model.fit(Xtrain, train_labels)
# Out:
# MultinomialNB()

# %% [markdown]
# # Get the probabilities Predictions from the model

# %%
y_pred_prob = model.predict_proba(Xtest)

# %%
y_pred_prob.shape
# Out:
# (1115, 2)

# %%
y_pred_prob.round(2)
# Out:
# array([[1.  , 0.  ],
#        [1.  , 0.  ],
#        [0.  , 1.  ],
#        ...,
#        [1.  , 0.  ],
#        [0.99, 0.01],
#        [0.  , 1.  ]])

# %% [markdown]
# # Get the class predictions from the model

# %%
y_pred = model.predict(Xtest)

# %% [markdown]
# # Observing Class Probabilities and Class prediction

# %%
df = pd.DataFrame({"Prob_class_0": y_pred_prob[:,0].round(2)
,"Prob_class_1": y_pred_prob[:,1].round(2)
,"Predicted class": y_pred})
df.head(20)
# Out:
#     Prob_class_0  Prob_class_1  Predicted class
# 0           1.00          0.00                0
# 1           1.00          0.00                0
# 2           0.00          1.00                1
# 3           1.00          0.00                0
# 4           0.00          1.00                1
# 5           1.00          0.00                0
# 6           1.00          0.00                0
# 7           0.99          0.01                0
# 8           1.00          0.00                0
# 9           1.00          0.00                0
# 10          1.00          0.00                0
# 11          0.00          1.00                1
# 12          1.00          0.00                0
# 13          1.00          0.00                0
# 14          1.00          0.00                0
# 15          1.00          0.00                0
# 16          0.98          0.02                0
# 17          0.00          1.00                1
# 18          1.00          0.00                0
# 19          1.00          0.00                0

# %% [markdown]
# # Create Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
cm = confusion_matrix(test_labels, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels= [0, 1])
disp.plot(xticks_rotation=45)
fig = disp.ax_.get_figure()
fig.set_figwidth(6)
fig.set_figheight(6)
plt.show()

# %% [markdown]
# # Calculate Accuracy, Precision, Recall and F1_Score

# %%
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score

# %%
print("Accuracy : %2.2f" % (accuracy_score(test_labels, y_pred, normalize=True)))
print("Precision : %2.2f" % (precision_score(test_labels, y_pred, average = 'macro')))
print("Recall : %2.2f" % (recall_score(test_labels, y_pred, average = 'macro')))
print("F1_Score : %2.2f" % (f1_score(test_labels, y_pred, average = 'macro')))
# Out:
# Accuracy : 0.98
# Precision : 0.98
# Recall : 0.95
# F1_Score : 0.96

# %% [markdown]
# # Enter your custom emails to check the model

# %%
email = "Hope you are fine and doing well. Could you please forward me the list of students?"

# %%
email = featurizer.transform([email])

# %%
print(model.predict(email))
# Out:
# [0]

# %%
email2 = "Congratulation!. you have won 5000 dollars. Click the link below to get the money"

# %%
email2 = featurizer.transform([email2])

# %%
print(model.predict(email2))
# Out:
# [1]
