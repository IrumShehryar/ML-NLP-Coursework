# %% [markdown]
# <a href="https://colab.research.google.com/github/IrumShehryar/ML-NLP-Coursework/blob/main/ml/12-unsupervised-learning/hierarchical-clustering/Project_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
style.use('dark_background')
import pandas as pd

# %% [markdown]
# ## Creating Random Data

# %%
x1 = 1 + np.random.randn(200,1)
x2 = 10 + np.random.randn(200,1)
x3 = 3 + np.random.randn(200,1)
x4 = 5 + np.random.randn(200,1)
x5 = -3 + np.random.randn(200,1)
x6 = 2 + np.random.randn(200,1)

# %%
X1 = np.hstack((x1,x2))
X2 = np.hstack((x3,x4))
X3 = np.hstack((x5,x6))

print(X1)
print(X1.shape)
# Out:
# [[ 1.21395817e+00  9.31723019e+00]
#  [ 2.68919776e+00  9.16654906e+00]
#  [ 2.70368851e+00  1.15064670e+01]
#  [-4.36230982e-01  9.89498427e+00]
#  [ 1.98749635e+00  1.07082703e+01]
#  [ 1.03073395e+00  1.07790426e+01]
#  [ 4.48932590e-01  1.15225379e+01]
#  [ 1.20133089e+00  9.88166057e+00]
#  [ 1.42763593e+00  9.92286283e+00]
#  [ 1.84517836e+00  1.15912279e+01]
#  [ 8.16424675e-01  1.01509927e+01]
#  [ 6.49428561e-01  1.01809664e+01]
#  [ 1.01913749e+00  1.06578319e+01]
#  [ 2.41585930e+00  1.13628883e+01]
#  [ 2.92693921e-01  1.00085413e+01]
#  [ 5.60670637e-01  1.17865863e+01]
#  [-1.77247714e-01  1.07011821e+01]
#  [-2.41105109e-01  9.60552698e+00]
#  [ 4.63362532e-01  1.05534377e+01]
#  [-2.08502252e-01  1.08507306e+01]
#  [ 5.76990978e-01  1.03845186e+01]
#  [ 4.03994356e-01  1.04619278e+01]
#  [ 3.95590125e-01  9.32427988e+00]
#  [ 1.34004108e+00  1.14244680e+01]
#  [ 1.07249387e+00  9.82179370e+00]
#  [ 1.01343360e+00  1.17644659e+01]
#  [ 9.37113323e-01  1.05439939e+01]
#  [ 2.85264276e+00  9.66302598e+00]
#  [ 1.16311815e+00  8.76459696e+00]
#  [ 3.90602610e+00  9.02305477e+00]
#  [ 1.00716493e+00  9.83464918e+00]
#  [ 2.12944689e+00  9.70884595e+00]
#  [-2.66039964e-01  8.88415234e+00]
#  [ 1.21150153e+00  1.01600155e+01]
#  [ 1.35682104e+00  9.88973829e+00]
#  [-3.64211566e-01  1.03190390e+01]
#  [ 3.05098846e+00  1.14356975e+01]
#  [ 6.54064919e-01  9.93190997e+00]
#  [ 9.49555799e-01  1.01477234e+01]
#  [ 2.35970542e+00  1.04372901e+01]
#  [-2.89946439e-01  9.46950600e+00]
#  [ 2.00372081e+00  9.23831569e+00]
#  [-1.17595836e+00  1.02857593e+01]
#  [ 9.95857955e-01  1.23096387e+01]
#  [ 1.29644544e+00  9.86402398e+00]
#  [ 1.31662142e+00  1.05752209e+01]
#  [ 1.36581999e+00  8.89868676e+00]
#  [ 8.61570972e-01  9.04536477e+00]
#  [ 1.01560583e+00  9.15541937e+00]
#  [ 3.24070394e-01  1.06927573e+01]
#  [ 3.86182991e-01  8.74386106e+00]
#  [ 1.15816755e+00  1.06997888e+01]
#  [ 1.28978875e+00  9.76227769e+00]
#  [ 1.70878372e+00  1.05374898e+01]
#  [ 1.11196093e+00  9.23453882e+00]
#  [ 6.40850746e-01  1.07892966e+01]
#  [ 8.31402952e-01  1.03471735e+01]
#  [ 2.72180750e+00  1.07959573e+01]
#  [ 6.64676449e-01  1.07594657e+01]
#  [ 2.67533055e+00  9.59569124e+00]
#  [ 2.29639134e+00  8.83756538e+00]
#  [ 1.11226155e+00  1.10936406e+01]
#  [ 9.26759672e-01  9.67090497e+00]
#  [ 4.50852503e-01  1.15111376e+01]
#  [ 4.72262857e-01  9.93820315e+00]
#  [-3.17609992e-03  9.61005197e+00]
#  [-1.90791087e-01  9.99248596e+00]
#  [ 2.36031463e+00  1.08169012e+01]
#  [ 1.97188367e-02  9.95510250e+00]
#  [ 1.95471146e+00  1.15955568e+01]
#  [-4.30017275e-01  8.44095896e+00]
#  [-8.92361191e-02  7.94215472e+00]
#  [ 2.11496254e+00  9.53604365e+00]
#  [ 6.74764440e-01  1.01462293e+01]
#  [ 1.39067064e+00  1.22198151e+01]
#  [ 6.71165665e-01  8.31526046e+00]]
# (200, 2)

# %%
X = np.vstack((X1,X2,X3))
print(X.shape)
# Out:
# (600, 2)

# %% [markdown]
# ## Using dendrograms to find the optimum number of clusters

# %%
import scipy
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
plt.figure(figsize = (10,7))
linkage_data = linkage(X, method='ward', metric='euclidean')
Dendrogram = dendrogram(linkage_data)
plt.title('Dendrogram', fontsize = 25)
plt.xlabel('Customers', fontsize = 15)
plt.ylabel('Euclidean distances',fontsize = 15)
plt.show()

# %% [markdown]
# ## Applying the hierarchical clustering to train the model

# %%
from sklearn.cluster import AgglomerativeClustering
hc = AgglomerativeClustering(n_clusters = 3)
y_pred = hc.fit_predict(X)

# %% [markdown]
# ## Visualize the clusters

# %%
plt.figure(figsize = (12,8))
plt.scatter(X[y_pred == 0, 0], X[y_pred == 0, 1], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(X[y_pred == 1, 0], X[y_pred == 1, 1], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(X[y_pred == 2, 0], X[y_pred == 2, 1], s = 100, c = 'green', label = 'Cluster 3')
plt.title('Clusters', fontsize = 25)
plt.xlabel('First Feature', fontsize = 15)
plt.ylabel('Second Feature', fontsize = 15)
plt.legend(fontsize = 15)
plt.show()

# %%
from sklearn.metrics import silhouette_score

# %%
print(f'Silhouette Score(n = 3) : {silhouette_score(X, y_pred)}')
# Out:
# Silhouette Score(n = 3) : 0.6905696357010294

# %%
hc = AgglomerativeClustering(n_clusters = 2)
y_pred = hc.fit_predict(X)
print(f'Silhouette Score(n = 2) : {silhouette_score(X, y_pred)}')
# Out:
# Silhouette Score(n = 2) : 0.614169005768314

# %%
hc = AgglomerativeClustering(n_clusters = 4)
y_pred = hc.fit_predict(X)
print(f'Silhouette Score(n = 4) : {silhouette_score(X, y_pred)}')
# Out:
# Silhouette Score(n = 4) : 0.574581292144858
