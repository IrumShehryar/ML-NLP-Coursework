# %% [markdown]
# <a href="https://colab.research.google.com/github/IrumShehryar/ML-NLP-Coursework/blob/main/ml/12-unsupervised-learning/PCA/Project_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
from matplotlib import style
style.use('dark_background')
import pandas as pd

# %%
X, y = make_blobs(n_samples = 2000, n_features = 5)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
data_rescaled = scaler.fit_transform(X)

# %% [markdown]
# # Selecting the Variance Ratio

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 0.99)
reduced = pca.fit_transform(data_rescaled)

# %%
reduced.shape
# Out:
# (2000, 4)

# %%
pca_02 = PCA(n_components = 4)
X_pca = pca_02.fit_transform(data_rescaled)

# %%
X_pca
# Out:
# array([[-0.70495206, -0.00297143, -0.08667256,  0.15024931],
#        [ 0.34430192, -0.36840502, -0.08613878,  0.0332367 ],
#        [ 0.37682078, -0.38443515,  0.03569012, -0.01322181],
#        ...,
#        [ 0.24383954,  0.54283183, -0.10279879,  0.02811357],
#        [-0.74069117,  0.01819519, -0.08824226, -0.01649082],
#        [-0.68360073,  0.06585695, -0.1022182 , -0.04344566]])

# %%
print(np.sum(pca_02.explained_variance_ratio_))
# Out:
# 0.9930982007260601
