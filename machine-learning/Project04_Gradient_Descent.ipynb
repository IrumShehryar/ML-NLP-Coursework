# %% [markdown]
# <a href="https://colab.research.google.com/github/IrumShehryar/ML-NLP-Coursework/blob/main/machine-learning/Project04_Gradient_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
style.use('dark_background')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/ML-course/Course Material/Supervised Machine Learning/Regression Analysis
# Out:
# /content/drive/MyDrive/ML-course/Course Material/Supervised Machine Learning/Regression Analysis

# %% [markdown]
# # Importing Data

# %%
data = pd.read_csv('Regression_Data.csv')
data
# Out:
#     Ind_Data  Dependent_Data
# 0        1.1           39343
# 1        1.3           46205
# 2        1.5           37731
# 3        2.0           43525
# 4        2.2           39891
# 5        2.9           56642
# 6        3.0           60150
# 7        3.2           54445
# 8        3.2           64445
# 9        3.7           57189
# 10       3.9           63218
# 11       4.0           55794
# 12       4.0           56957
# 13       4.1           57081
# 14       4.5           61111
# 15       4.9           67938
# 16       5.1           66029
# 17       5.3           83088
# 18       5.9           81363
# 19       6.0           93940
# 20       6.8           91738
# 21       7.1           98273
# 22       7.9          101302
# 23       8.2          113812
# 24       8.7          109431
# 25       9.0          105582
# 26       9.5          116969
# 27       9.6          112635
# 28      10.3          122391
# 29      10.5          121872

# %% [markdown]
# # Extracting Dependent and Independent Variables

# %%
X = data['Ind_Data'].values
y = data['Dependent_Data'].values

# %% [markdown]
# # Visualize the Scatter plot between X and y

# %%
plt.figure(figsize=(12,8))
plt.scatter(X, y, marker = "x", color = 'g', lw = 5)
plt.xlabel('Independent Data', fontsize = 16)
plt.ylabel('Dependent Data', fontsize = 16)
plt.xlim([0, X.max()])
plt.ylim([0, y.max()])
plt.show()

# %% [markdown]
# # Reshaping X and y and appending ones at the first column of X

# %%
X = X.reshape(-1,1)

# %%
y = y.reshape(-1,1)

# %%
ones = np.ones((len(X),1))

# %%
X_input = np.concatenate((ones,X),axis=1)
X_input
# Out:
# array([[ 1. ,  1.1],
#        [ 1. ,  1.3],
#        [ 1. ,  1.5],
#        [ 1. ,  2. ],
#        [ 1. ,  2.2],
#        [ 1. ,  2.9],
#        [ 1. ,  3. ],
#        [ 1. ,  3.2],
#        [ 1. ,  3.2],
#        [ 1. ,  3.7],
#        [ 1. ,  3.9],
#        [ 1. ,  4. ],
#        [ 1. ,  4. ],
#        [ 1. ,  4.1],
#        [ 1. ,  4.5],
#        [ 1. ,  4.9],
#        [ 1. ,  5.1],
#        [ 1. ,  5.3],
#        [ 1. ,  5.9],
#        [ 1. ,  6. ],
#        [ 1. ,  6.8],
#        [ 1. ,  7.1],
#        [ 1. ,  7.9],
#        [ 1. ,  8.2],
#        [ 1. ,  8.7],
#        [ 1. ,  9. ],
#        [ 1. ,  9.5],
#        [ 1. ,  9.6],
#        [ 1. , 10.3],
#        [ 1. , 10.5]])

# %%
weights = np.random.randn(len(X[0])+1, 1)  # Initialize the values of weights
weights
# Out:
# array([[1.72761916],
#        [0.07747799]])

# %% [markdown]
# #Equation of Gradient Descent

# %% [markdown]
# ![Untitled.png](data:image/png;base64,...)

# %% [markdown]
# # Applying Gradient Descent

# %%
weights = np.random.randn(len(X[0])+1, 1)  # Initialize the values of weights
n = len(X)
iterations = 3000
learningrate = 0.01
for i in range(iterations):
    gradients = -2/n * np.dot(X_input.T,(y - np.dot(X_input, weights)))    # Gradient Calculation
    weights = weights - learningrate * gradients # Weights update

# %%
weights
# Out:
# array([[25792.12870503],
#        [ 9449.97293081]])

# %% [markdown]
# # Testing and Evaluating the Model Evaluation

# %%
test_data = np.linspace(0,11,30).reshape(-1,1)

# %%
test_data
# Out:
# array([[ 0.        ],
#        [ 0.37931034],
#        [ 0.75862069],
#        [ 1.13793103],
#        [ 1.51724138],
#        [ 1.89655172],
#        [ 2.27586207],
#        [ 2.65517241],
#        [ 3.03448276],
#        [ 3.4137931 ],
#        [ 3.79310345],
#        [ 4.17241379],
#        [ 4.55172414],
#        [ 4.93103448],
#        [ 5.31034483],
#        [ 5.68965517],
#        [ 6.06896552],
#        [ 6.44827586],
#        [ 6.82758621],
#        [ 7.20689655],
#        [ 7.5862069 ],
#        [ 7.96551724],
#        [ 8.34482759],
#        [ 8.72413793],
#        [ 9.10344828],
#        [ 9.48275862],
#        [ 9.86206897],
#        [10.24137931],
#        [10.62068966],
#        [11.        ]])

# %%
ones = np.ones((len(test_data),1))

# %%
X_test = np.concatenate((ones,test_data),axis=1)

# %%
X_test
# Out:
# array([[ 1.        ,  0.        ],
#        [ 1.        ,  0.37931034],
#        [ 1.        ,  0.75862069],
#        [ 1.        ,  1.13793103],
#        [ 1.        ,  1.51724138],
#        [ 1.        ,  1.89655172],
#        [ 1.        ,  2.27586207],
#        [ 1.        ,  2.65517241],
#        [ 1.        ,  3.03448276],
#        [ 1.        ,  3.4137931 ],
#        [ 1.        ,  3.79310345],
#        [ 1.        ,  4.17241379],
#        [ 1.        ,  4.55172414],
#        [ 1.        ,  4.93103448],
#        [ 1.        ,  5.31034483],
#        [ 1.        ,  5.68965517],
#        [ 1.        ,  6.06896552],
#        [ 1.        ,  6.44827586],
#        [ 1.        ,  6.82758621],
#        [ 1.        ,  7.20689655],
#        [ 1.        ,  7.5862069 ],
#        [ 1.        ,  7.96551724],
#        [ 1.        ,  8.34482759],
#        [ 1.        ,  8.72413793],
#        [ 1.        ,  9.10344828],
#        [ 1.        ,  9.48275862],
#        [ 1.        ,  9.86206897],
#        [ 1.        , 10.24137931],
#        [ 1.        , 10.62068966],
#        [ 1.        , 11.        ]])

# %%
y_test = np.linspace(np.min(y), np.max(y), 30)

# %%
y_pred = np.dot(X_test, weights)  # y_pred = X * W

# %% [markdown]
# # Visualizing the Model Performance

# %%
plt.figure(figsize=(12,8))
plt.xlim([0, X_test.max()])
plt.ylim([0, y_pred.max()])
plt.plot(test_data, y_pred, color='blue', label='Predicted values', linewidth = 3)
plt.scatter(X, y, c='green', label='Target values', linewidth = 5)
plt.xlabel('Independent Data', fontsize = 16)
plt.ylabel('Dependent Data', fontsize = 16)
plt.legend(fontsize = 16)
plt.show()

# %% [markdown]
# # Evaluating Regression Metrics

# %%
from sklearn import metrics
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('MAE:', metrics.mean_absolute_error(y_test, y_pred))
print('R2:', metrics.r2_score(y_test, y_pred))
# Out:
# RMSE: 6197.476063788273
# MAE: 5247.971487526202
# R2: 0.9398423672608242

# %% [markdown]
# # Comparing With Least Square

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()  # instantiate Linear Regression

# %%
X = X.reshape(-1,1)

# %%
lr.fit(X,y)  # Sk-Learn also does least square fitting
print("Intercept:", lr.intercept_)
print("Coefficient:", lr.coef_)
# Out:
# Intercept: [25792.20019867]
# Coefficient: [[9449.96232146]]

# %%
test_data = test_data.reshape(-1,1)

# %%
y_pred = lr.predict(test_data)

# %%
plt.figure(figsize=(12,8))
plt.xlim([0, test_data.max()])
plt.ylim([0, y_pred.max()])
plt.plot(test_data, y_pred, color='blue', label='Predicted values', linewidth = 3)
plt.scatter(X, y, c='green', label='Target values', linewidth = 5)
plt.xlabel('Independent Data', fontsize = 15)
plt.ylabel('Dependent Data', fontsize = 15)
plt.legend(fontsize = 16)
plt.show()

# %%
from sklearn import metrics
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('MAE:', metrics.mean_absolute_error(y_test, y_pred))
print('R2:', metrics.r2_score(y_test, y_pred))
# Out:
# RMSE: 6197.438841666302
# MAE: 5247.939884570575
# R2: 0.9398430898737059
